# %% [markdown]
# # Activity 1.04: Connect Four
#
# In this activity, we will practice using the EasyAI library and develop a heuristic. We will be using the game Connect Four for this. The game board is seven cells wide and seven cells high. When you make a move, you can only select the column in which you drop your token. Then, gravity pulls the token down to the lowest possible empty cell. Your objective is to connect four of your own tokens horizontally, vertically, or diagonally, before your opponent does, or you run out of empty spaces.
#
# The rules of the game can be found [here](https://en.wikipedia.org/wiki/Connect_Four).
#
#   > **Hints**
#   >  1. Define the board and write the init method to generate all the possible winning combinations in the game and save them for future use.
#   >  2. Write a function to enumerate all the possible moves. Then, for each column, check whether there is an unoccupied field. If there is one, make the column a possible move.
#   >  3. Create a function to make a move (it will be similar to the possible move function), and then check the column of the move and find the first empty cell, starting from the bottom.
#   >  4. Reuse the lose function from the tic-tac-toe example.
#   >  5. Implement the show method that prints the board and try out the game. You can reuse the tic-tac-toe implementation and just change the `show` and `scoring` variables
#
#
# Output:
#
# ```
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
#
# Player 1 what do you play ?  1
#
# Move #1: player 1 plays 1 :
#
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# O . . . . . .
#
# Move #2: player 2 plays 1 :
#
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . . . . .
# O . . . . . .
#
# Player 1 what do you play ?  2
#
# Move #3: player 1 plays 2 :
#
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . . . . .
# O O . . . . .
#
# Move #4: player 2 plays 1 :
#
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . . . . .
# X . . . . . .
# O O . . . . .
#
# Player 1 what do you play ?  3
#
# Move #5: player 1 plays 3 :
#
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . . . . .
# X . . . . . .
# O O O . . . .
#
# Move #6: player 2 plays 4 :
#
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . . . . .
# X . . . . . .
# O O O X . . .
#
# Player 1 what do you play ?  4
#
# Move #7: player 1 plays 4 :
#
# . . . . . . .
# . . . . . . .
# . . . . . . .
# X . . . . . .
# X . . O . . .
# O O O X . . .
#
# Move #8: player 2 plays 1 :
#
# . . . . . . .
# . . . . . . .
# X . . . . . .
# X . . . . . .
# X . . O . . .
# O O O X . . .
#
# Player 1 what do you play ?  5
#
# Move #9: player 1 plays 5 :
#
# . . . . . . .
# . . . . . . .
# X . . . . . .
# X . . . . . .
# X . . O . . .
# O O O X O . .
#
# Move #10: player 2 plays 1 :
#
# . . . . . . .
# X . . . . . .
# X . . . . . .
# X . . . . . .
# X . . O . . .
# O O O X O . .
# ```
